# %% [markdown]
# <a href="https://colab.research.google.com/github/MySureStart/mit_futuremakers_summer_2023-IamJesseP/blob/main/Module_12_Regularization/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image_2021-10-30_133041.png](data:image/png;base64,...)

# %% [markdown]
# #Objective
# * To acquaint you with the problem of overfit models and to mitigate it with regularization

# %%
# Basic packages
import pandas as pd
import numpy as np
import re
import collections
import matplotlib.pyplot as plt
from pathlib import Path

# Packages for data preparation
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from keras.preprocessing.text import Tokenizer
from keras.utils.np_utils import to_categorical
from sklearn.preprocessing import LabelEncoder

import nltk
nltk.download('stopwords')

# Packages for modeling
import tensorflow as tf
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import regularizers

NB_WORDS = 10000  # Parameter indicating the number of words we'll put in the dictionary
NB_START_EPOCHS = 20  # Number of epochs we usually start to train with
BATCH_SIZE = 512  # Size of the batches used in the mini-batch gradient descent
MAX_LEN = 20  # Maximum number of words in a sequence

root = Path('../content/')
input_path = root / 'input/'
ouput_path = root / 'output/'
source_path = root / 'source/'

def deep_model(model, X_train, y_train, X_valid, y_valid):
    model.compile(optimizer='rmsprop'
                  , loss='categorical_crossentropy'
                  , metrics=['accuracy'])

    history = model.fit(X_train
                       , y_train
                       , epochs=NB_START_EPOCHS
                       , batch_size=BATCH_SIZE
                       , validation_data=(X_valid, y_valid)
                       , verbose=1)
    return history

def eval_metric(model, history, metric_name):
    metric = history.history[metric_name]
    val_metric = history.history['val_' + metric_name]

    e = range(1, NB_START_EPOCHS + 1)

    plt.plot(e, metric, 'bo', label='Train ' + metric_name)
    plt.plot(e, val_metric, 'b', label='Validation ' + metric_name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_name)
    plt.title('Comparing training and validation ' + metric_name + ' for ' + model.name)
    plt.legend()
    plt.show()

def remove_stopwords(input_text):
    stopwords_list = stopwords.words('english')
    # Some words which might indicate a certain sentiment are kept via a whitelist
    whitelist = ["n't", "not", "no"]
    words = input_text.split()
    clean_words = [word for word in words if (word not in stopwords_list or word in whitelist) and len(word) > 1]
    return " ".join(clean_words)

def remove_mentions(input_text):
    return re.sub(r'@\w+', '', input_text)

def test_model(model, X_train, y_train, X_test, y_test, epoch_stop):
    model.fit(X_train
              , y_train
              , epochs=epoch_stop
              , batch_size=BATCH_SIZE
              , verbose=1)
    results = model.evaluate(X_test, y_test)
    print()
    print('Test accuracy: {0:.2f}%'.format(results[1]*100))
    return results

def compare_models_by_metric(model_1, model_2, model_hist_1, model_hist_2, metric):
    metric_model_1 = model_hist_1.history[metric]
    metric_model_2 = model_hist_2.history[metric]

    e = range(1, NB_START_EPOCHS + 1)

    metrics_dict = {
        'acc' : 'Training Accuracy',
        'loss' : 'Training Loss',
        'val_acc' : 'Validation accuracy',
        'val_loss' : 'Validation loss'
    }

    metric_label = metrics_dict[metric]

    plt.plot(e, metric_model_1, 'bo', label=model_1.name)
    plt.plot(e, metric_model_2, 'b', label=model_2.name)
    plt.xlabel('Epoch number')
    plt.ylabel(metric_label)
    plt.title('Comparing ' + metric_label + ' between models')
    plt.legend()
    plt.show()

def optimal_epoch(model_hist):
    min_epoch = np.argmin(model_hist.history['val_loss']) + 1
    print("Minimum validation loss reached in epoch {}".format(min_epoch))
    return min_epoch

! gdown --id 1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
! mkdir input/
! mv Tweets.csv input/

df = pd.read_csv(input_path / 'Tweets.csv')
df = df.reindex(np.random.permutation(df.index))
df = df[['text', 'airline_sentiment']]
df.text = df.text.apply(remove_stopwords).apply(remove_mentions)

X_train, X_test, y_train, y_test = train_test_split(df.text, df.airline_sentiment, test_size=0.1, random_state=37)

tk = Tokenizer(num_words=NB_WORDS,
               filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~\t\n',
               lower=True,
               char_level=False,
               split=' ')
tk.fit_on_texts(X_train)

X_train_oh = tk.texts_to_matrix(X_train, mode='binary')
X_test_oh = tk.texts_to_matrix(X_test, mode='binary')

le = LabelEncoder()
y_train_le = le.fit_transform(y_train)
y_test_le = le.transform(y_test)
y_train_oh = to_categorical(y_train_le)
y_test_oh = to_categorical(y_test_le)

X_train_rest, X_valid, y_train_rest, y_valid = train_test_split(X_train_oh, y_train_oh, test_size=0.1, random_state=37)

base_model = models.Sequential()
base_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
base_model.add(layers.Dense(64, activation='relu'))
base_model.add(layers.Dense(3, activation='softmax'))
base_history = deep_model(base_model, X_train_rest, y_train_rest, X_valid, y_valid)
base_min = optimal_epoch(base_history)

reduced_model = models.Sequential()
reduced_model.add(layers.Dense(16, activation='relu', input_shape=(NB_WORDS,)))
reduced_model.add(layers.Dense(3, activation='softmax'))
reduced_history = deep_model(reduced_model, X_train_rest, y_train_rest, X_valid, y_valid)
reduced_min = optimal_epoch(reduced_history)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1QFupRVBpstzf_D6NiFvYQIO-MPuiwG9u
# To: /content/Tweets.csv
# 100% 3.42M/3.42M [00:00<00:00, 43.3MB/s]
# Epoch 1/20
# 24/24 [==============================] - 6s 80ms/step - loss: 0.8929 - accuracy: 0.6093 - val_loss: 0.7219 - val_accuracy: 0.6669
# Epoch 2/20
# 24/24 [==============================] - 2s 65ms/step - loss: 0.6429 - accuracy: 0.7266 - val_loss: 0.5785 - val_accuracy: 0.7671
# Epoch 3/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.4936 - accuracy: 0.8189 - val_loss: 0.5283 - val_accuracy: 0.7914
# Epoch 4/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.4017 - accuracy: 0.8557 - val_loss: 0.5106 - val_accuracy: 0.8065
# Epoch 5/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.3370 - accuracy: 0.8806 - val_loss: 0.5251 - val_accuracy: 0.7898
# Epoch 6/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.2876 - accuracy: 0.8992 - val_loss: 0.5405 - val_accuracy: 0.7989
# Epoch 7/20
# 24/24 [==============================] - 2s 70ms/step - loss: 0.2464 - accuracy: 0.9137 - val_loss: 0.5710 - val_accuracy: 0.7959
# Epoch 8/20
# 24/24 [==============================] - 2s 95ms/step - loss: 0.2124 - accuracy: 0.9298 - val_loss: 0.5947 - val_accuracy: 0.8012
# Epoch 9/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.1840 - accuracy: 0.9397 - val_loss: 0.6359 - val_accuracy: 0.7906
# Epoch 10/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.1591 - accuracy: 0.9477 - val_loss: 0.6711 - val_accuracy: 0.7853
# Epoch 11/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.1384 - accuracy: 0.9579 - val_loss: 0.7087 - val_accuracy: 0.7815
# Epoch 12/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.1202 - accuracy: 0.9617 - val_loss: 0.7505 - val_accuracy: 0.7785
# Epoch 13/20
# 24/24 [==============================] - 1s 62ms/step - loss: 0.1068 - accuracy: 0.9658 - val_loss: 0.7939 - val_accuracy: 0.7777
# Epoch 14/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0921 - accuracy: 0.9699 - val_loss: 0.8348 - val_accuracy: 0.7709
# Epoch 15/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0826 - accuracy: 0.9728 - val_loss: 0.8711 - val_accuracy: 0.7785
# Epoch 16/20
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0729 - accuracy: 0.9769 - val_loss: 0.9307 - val_accuracy: 0.7754
# Epoch 17/20
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0648 - accuracy: 0.9799 - val_loss: 0.9633 - val_accuracy: 0.7709
# Epoch 18/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0587 - accuracy: 0.9821 - val_loss: 0.9906 - val_accuracy: 0.7693
# Epoch 19/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0516 - accuracy: 0.9846 - val_loss: 1.0458 - val_accuracy: 0.7595
# Epoch 20/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0478 - accuracy: 0.9860 - val_loss: 1.0695 - val_accuracy: 0.7686
# Minimum validation loss reached in epoch 4
# Epoch 1/20
# 24/24 [==============================] - 2s 51ms/step - loss: 0.9439 - accuracy: 0.6267 - val_loss: 0.8349 - val_accuracy: 0.6464
# Epoch 2/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.7910 - accuracy: 0.6520 - val_loss: 0.7413 - val_accuracy: 0.6677
# Epoch 3/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.7090 - accuracy: 0.6825 - val_loss: 0.6858 - val_accuracy: 0.6904
# Epoch 4/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.6497 - accuracy: 0.7139 - val_loss: 0.6480 - val_accuracy: 0.7200
# Epoch 5/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.6026 - accuracy: 0.7548 - val_loss: 0.6196 - val_accuracy: 0.7413
# Epoch 6/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.5624 - accuracy: 0.7907 - val_loss: 0.5967 - val_accuracy: 0.7534
# Epoch 7/20
# 24/24 [==============================] - 1s 52ms/step - loss: 0.5268 - accuracy: 0.8138 - val_loss: 0.5767 - val_accuracy: 0.7709
# Epoch 8/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.4944 - accuracy: 0.8329 - val_loss: 0.5609 - val_accuracy: 0.7800
# Epoch 9/20
# 24/24 [==============================] - 1s 48ms/step - loss: 0.4653 - accuracy: 0.8458 - val_loss: 0.5481 - val_accuracy: 0.7921
# Epoch 10/20
# 24/24 [==============================] - 1s 36ms/step - loss: 0.4393 - accuracy: 0.8559 - val_loss: 0.5365 - val_accuracy: 0.7951
# Epoch 11/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.4152 - accuracy: 0.8649 - val_loss: 0.5277 - val_accuracy: 0.7951
# Epoch 12/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.3934 - accuracy: 0.8727 - val_loss: 0.5221 - val_accuracy: 0.7944
# Epoch 13/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.3740 - accuracy: 0.8781 - val_loss: 0.5178 - val_accuracy: 0.7974
# Epoch 14/20
# 24/24 [==============================] - 1s 39ms/step - loss: 0.3564 - accuracy: 0.8851 - val_loss: 0.5156 - val_accuracy: 0.7989
# Epoch 15/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.3405 - accuracy: 0.8891 - val_loss: 0.5133 - val_accuracy: 0.8005
# Epoch 16/20
# 24/24 [==============================] - 1s 38ms/step - loss: 0.3258 - accuracy: 0.8937 - val_loss: 0.5142 - val_accuracy: 0.7967
# Epoch 17/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.3125 - accuracy: 0.8979 - val_loss: 0.5154 - val_accuracy: 0.7982
# Epoch 18/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.3004 - accuracy: 0.9013 - val_loss: 0.5172 - val_accuracy: 0.7997
# Epoch 19/20
# 24/24 [==============================] - 1s 37ms/step - loss: 0.2888 - accuracy: 0.9055 - val_loss: 0.5208 - val_accuracy: 0.7944
# Epoch 20/20
# 24/24 [==============================] - 1s 45ms/step - loss: 0.2781 - accuracy: 0.9083 - val_loss: 0.5256 - val_accuracy: 0.7914
# Minimum validation loss reached in epoch 15

# %% [markdown]
# # Applying regularization
#
# You may be familiar with Occam's Razor principle: given two explanations for something, the explanation most likely to be correct is the "simplest" one, the one that makes the least amount of assumptions. This also applies to the models learned by neural networks: given some training data and a network architecture, there are multiple sets of weights values (multiple models) that could explain the data, and simpler models are less likely to overfit than complex ones.
#
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the squared "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# L1 regularization pushes weights towards exactly zero encouraging a sparse model. L2 regularization will penalize the weights parameters without making them sparse since the penalty goes to zero for small weights-one reason why L2 is more common.
#
# In `tf.keras`, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
reg_model = models.Sequential()
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu', input_shape=(NB_WORDS,)))
reg_model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.001), activation='relu'))
reg_model.add(layers.Dense(3, activation='softmax'))
reg_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 64)                640064
#
#  dense_6 (Dense)             (None, 64)                4160
#
#  dense_7 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
reg_history = deep_model(reg_model, X_train_rest, y_train_rest, X_valid, y_valid)
reg_min = optimal_epoch(reg_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 4s 77ms/step - loss: 1.0056 - accuracy: 0.6241 - val_loss: 0.8552 - val_accuracy: 0.6646
# Epoch 2/20
# 24/24 [==============================] - 2s 64ms/step - loss: 0.7844 - accuracy: 0.7201 - val_loss: 0.7379 - val_accuracy: 0.7618
# Epoch 3/20
# 24/24 [==============================] - 2s 66ms/step - loss: 0.6531 - accuracy: 0.8209 - val_loss: 0.6768 - val_accuracy: 0.7777
# Epoch 4/20
# 24/24 [==============================] - 2s 62ms/step - loss: 0.5562 - accuracy: 0.8528 - val_loss: 0.6506 - val_accuracy: 0.7929
# Epoch 5/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.4891 - accuracy: 0.8715 - val_loss: 0.6406 - val_accuracy: 0.7959
# Epoch 6/20
# 24/24 [==============================] - 2s 79ms/step - loss: 0.4407 - accuracy: 0.8898 - val_loss: 0.6404 - val_accuracy: 0.7967
# Epoch 7/20
# 24/24 [==============================] - 3s 111ms/step - loss: 0.4024 - accuracy: 0.9020 - val_loss: 0.6590 - val_accuracy: 0.7914
# Epoch 8/20
# 24/24 [==============================] - 2s 67ms/step - loss: 0.3722 - accuracy: 0.9152 - val_loss: 0.6728 - val_accuracy: 0.7944
# Epoch 9/20
# 24/24 [==============================] - 1s 61ms/step - loss: 0.3474 - accuracy: 0.9235 - val_loss: 0.7037 - val_accuracy: 0.7838
# Epoch 10/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.3270 - accuracy: 0.9299 - val_loss: 0.7042 - val_accuracy: 0.7906
# Epoch 11/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.3090 - accuracy: 0.9384 - val_loss: 0.7110 - val_accuracy: 0.7853
# Epoch 12/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.2933 - accuracy: 0.9438 - val_loss: 0.7323 - val_accuracy: 0.7868
# Epoch 13/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.2787 - accuracy: 0.9504 - val_loss: 0.7458 - val_accuracy: 0.7868
# Epoch 14/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.2666 - accuracy: 0.9554 - val_loss: 0.7488 - val_accuracy: 0.7906
# Epoch 15/20
# 24/24 [==============================] - 2s 97ms/step - loss: 0.2557 - accuracy: 0.9578 - val_loss: 0.7851 - val_accuracy: 0.7739
# Epoch 16/20
# 24/24 [==============================] - 2s 79ms/step - loss: 0.2451 - accuracy: 0.9608 - val_loss: 0.7788 - val_accuracy: 0.7830
# Epoch 17/20
# 24/24 [==============================] - 3s 112ms/step - loss: 0.2376 - accuracy: 0.9644 - val_loss: 0.8003 - val_accuracy: 0.7785
# Epoch 18/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.2277 - accuracy: 0.9696 - val_loss: 0.8152 - val_accuracy: 0.7724
# Epoch 19/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.2230 - accuracy: 0.9685 - val_loss: 0.8032 - val_accuracy: 0.7739
# Epoch 20/20
# 24/24 [==============================] - 1s 60ms/step - loss: 0.2143 - accuracy: 0.9733 - val_loss: 0.8179 - val_accuracy: 0.7868
# Minimum validation loss reached in epoch 6

# %% [markdown]
# For the regularized model we notice that it starts overfitting in the same epoch as the baseline model. However, the loss increases much slower afterwards.

# %%
eval_metric(reg_model, reg_history, 'loss')

# %%
compare_models_by_metric(base_model, reg_model, base_history, reg_history, 'val_loss')

# %% [markdown]
# ## Question 1
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 1

# %%
weights = [-5, 4, -3, 2, 1]

# This is the L1 regularizer

def l1_norm(weights):
    reg = np.sum(np.abs(weights))
    return reg

print(l1_norm(weights))
# Out:
# 15

# %% [markdown]
# ## Question 2
#
# First identify (provide the name of) and then code the regularizer which is used in the following loss function:
#
# $$cost = (\mathbf{y} - \mathbf{x}W)^2 + λ||W||_2^2$$
#
# Let's assume $w = [-5, 4, -3, 2, 1]$

# %% [markdown]
# ###  Answer 2

# %%
weights = [-5, 4, -3, 2, 1]

def l2_norm(weights):
    reg =  np.sum(np.square(weights))
    return reg

print(l2_norm(weights))
# Out:
# 55

# %% [markdown]
# ## Adding dropout layers
# Add dropout
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto.
#
# The intuitive explanation for dropout is that because individual nodes in the network cannot rely on the output of the others, each node must output features that are useful on their own.
#
# Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1].
#
# The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In `tf.keras` you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our network to see how well they do at reducing overfitting:

# %%
drop_model = models.Sequential()
drop_model.add(layers.Dense(64, activation='relu', input_shape=(NB_WORDS,)))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(64, activation='relu'))
drop_model.add(layers.Dropout(0.5))
drop_model.add(layers.Dense(3, activation='softmax'))
drop_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_8 (Dense)             (None, 64)                640064
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_9 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 644,419
# Trainable params: 644,419
# Non-trainable params: 0
# _________________________________________________________________

# %%
drop_history = deep_model(drop_model, X_train_rest, y_train_rest, X_valid, y_valid)
drop_min = optimal_epoch(drop_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 5s 146ms/step - loss: 0.9752 - accuracy: 0.5759 - val_loss: 0.8069 - val_accuracy: 0.6328
# Epoch 2/20
# 24/24 [==============================] - 2s 104ms/step - loss: 0.7807 - accuracy: 0.6328 - val_loss: 0.6943 - val_accuracy: 0.6639
# Epoch 3/20
# 24/24 [==============================] - 3s 105ms/step - loss: 0.6745 - accuracy: 0.7097 - val_loss: 0.6028 - val_accuracy: 0.7610
# Epoch 4/20
# 24/24 [==============================] - 3s 121ms/step - loss: 0.5803 - accuracy: 0.7850 - val_loss: 0.5484 - val_accuracy: 0.7959
# Epoch 5/20
# 24/24 [==============================] - 2s 63ms/step - loss: 0.5072 - accuracy: 0.8154 - val_loss: 0.5271 - val_accuracy: 0.7989
# Epoch 6/20
# 24/24 [==============================] - 1s 50ms/step - loss: 0.4569 - accuracy: 0.8387 - val_loss: 0.5176 - val_accuracy: 0.7974
# Epoch 7/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.4118 - accuracy: 0.8556 - val_loss: 0.5208 - val_accuracy: 0.8012
# Epoch 8/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3778 - accuracy: 0.8677 - val_loss: 0.5251 - val_accuracy: 0.7929
# Epoch 9/20
# 24/24 [==============================] - 1s 53ms/step - loss: 0.3457 - accuracy: 0.8803 - val_loss: 0.5388 - val_accuracy: 0.8027
# Epoch 10/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.3196 - accuracy: 0.8894 - val_loss: 0.5481 - val_accuracy: 0.7997
# Epoch 11/20
# 24/24 [==============================] - 1s 54ms/step - loss: 0.3006 - accuracy: 0.8939 - val_loss: 0.5606 - val_accuracy: 0.8005
# Epoch 12/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.2704 - accuracy: 0.9072 - val_loss: 0.5815 - val_accuracy: 0.7959
# Epoch 13/20
# 24/24 [==============================] - 2s 90ms/step - loss: 0.2503 - accuracy: 0.9138 - val_loss: 0.6031 - val_accuracy: 0.7997
# Epoch 14/20
# 24/24 [==============================] - 2s 72ms/step - loss: 0.2391 - accuracy: 0.9192 - val_loss: 0.6177 - val_accuracy: 0.7967
# Epoch 15/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.2223 - accuracy: 0.9276 - val_loss: 0.6351 - val_accuracy: 0.7959
# Epoch 16/20
# 24/24 [==============================] - 1s 58ms/step - loss: 0.2026 - accuracy: 0.9356 - val_loss: 0.6544 - val_accuracy: 0.7921
# Epoch 17/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.1883 - accuracy: 0.9363 - val_loss: 0.6751 - val_accuracy: 0.7929
# Epoch 18/20
# 24/24 [==============================] - 1s 59ms/step - loss: 0.1717 - accuracy: 0.9435 - val_loss: 0.7108 - val_accuracy: 0.7929
# Epoch 19/20
# 24/24 [==============================] - 1s 57ms/step - loss: 0.1591 - accuracy: 0.9480 - val_loss: 0.7301 - val_accuracy: 0.7929
# Epoch 20/20
# 24/24 [==============================] - 1s 56ms/step - loss: 0.1488 - accuracy: 0.9514 - val_loss: 0.7536 - val_accuracy: 0.7936
# Minimum validation loss reached in epoch 6

# %%
eval_metric(drop_model, drop_history, 'loss')

# %% [markdown]
# The model with dropout layers starts overfitting later than the baseline model. The loss also increases slower than the baseline model.

# %%
compare_models_by_metric(base_model, drop_model, base_history, drop_history, 'val_loss')

# %% [markdown]
# The model with the Dropout layers starts overfitting later. Compared to the baseline model the loss also remains much lower.

# %% [markdown]
# ## Combined L2 + dropout

# %%
combined_model = tf.keras.Sequential([
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu', input_shape=(NB_WORDS,)),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(512, kernel_regularizer=regularizers.l2(0.0001),
                 activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(3)
])

# %%
combined_history = deep_model(combined_model, X_train_rest, y_train_rest, X_valid, y_valid)
combined_min = optimal_epoch(combined_history)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 10s 370ms/step - loss: nan - accuracy: 0.6129 - val_loss: nan - val_accuracy: 0.6328
# Epoch 2/20
# 24/24 [==============================] - 7s 297ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 3/20
# 24/24 [==============================] - 9s 368ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 4/20
# 24/24 [==============================] - 7s 286ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 5/20
# 24/24 [==============================] - 9s 400ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 6/20
# 24/24 [==============================] - 9s 341ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 7/20
# 24/24 [==============================] - 7s 290ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 8/20
# 24/24 [==============================] - 8s 331ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 9/20
# 24/24 [==============================] - 7s 291ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 10/20
# 24/24 [==============================] - 8s 325ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 11/20
# 24/24 [==============================] - 8s 336ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 12/20
# 24/24 [==============================] - 7s 290ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 13/20
# 24/24 [==============================] - 8s 353ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 14/20
# 24/24 [==============================] - 7s 288ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 15/20
# 24/24 [==============================] - 8s 338ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 16/20
# 24/24 [==============================] - 8s 344ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 17/20
# 24/24 [==============================] - 7s 286ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 18/20
# 24/24 [==============================] - 8s 336ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 19/20
# 24/24 [==============================] - 7s 285ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Epoch 20/20
# 24/24 [==============================] - 8s 334ms/step - loss: nan - accuracy: 0.6246 - val_loss: nan - val_accuracy: 0.6328
# Minimum validation loss reached in epoch 1

# %%
eval_metric(combined_model, combined_history, 'loss')

# %%
compare_models_by_metric(base_model, combined_model, base_history, combined_history, 'val_loss')

# %% [markdown]
# ## Question 3
#
# When does it make sense to add both L2 regularization and Dropout?
#
# And what did doing so achieve in this case?

# %% [markdown]
# ### Answer 3
#
# Both are good when we want to prevent overfitting.

# %% [markdown]
# #Training on the full train data and evaluation on test data
# At first sight the reduced model seems to be the best model for generalization. But let's check that on the test set.

# %%
base_results = test_model(base_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, base_min)
# Out:
# Epoch 1/4
# 26/26 [==============================] - 2s 85ms/step - loss: 0.1449 - accuracy: 0.9646
# Epoch 2/4
# 26/26 [==============================] - 2s 78ms/step - loss: 0.1016 - accuracy: 0.9726
# Epoch 3/4
# 26/26 [==============================] - 1s 50ms/step - loss: 0.0801 - accuracy: 0.9776
# Epoch 4/4
# 26/26 [==============================] - 1s 49ms/step - loss: 0.0658 - accuracy: 0.9819
# 46/46 [==============================] - 0s 4ms/step - loss: 0.8975 - accuracy: 0.7876
#
# Test accuracy: 78.76%

# %%
reduced_results = test_model(reduced_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reduced_min)
# Out:
# Epoch 1/15
# 26/26 [==============================] - 1s 36ms/step - loss: 0.2940 - accuracy: 0.8999
# Epoch 2/15
# 26/26 [==============================] - 1s 32ms/step - loss: 0.2823 - accuracy: 0.9055
# Epoch 3/15
# 26/26 [==============================] - 1s 40ms/step - loss: 0.2720 - accuracy: 0.9075
# Epoch 4/15
# 26/26 [==============================] - 1s 43ms/step - loss: 0.2623 - accuracy: 0.9127
# Epoch 5/15
# 26/26 [==============================] - 1s 44ms/step - loss: 0.2534 - accuracy: 0.9152
# Epoch 6/15
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2448 - accuracy: 0.9177
# Epoch 7/15
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2366 - accuracy: 0.9216
# Epoch 8/15
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2292 - accuracy: 0.9243
# Epoch 9/15
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2220 - accuracy: 0.9259
# Epoch 10/15
# 26/26 [==============================] - 1s 29ms/step - loss: 0.2150 - accuracy: 0.9289
# Epoch 11/15
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2084 - accuracy: 0.9314
# Epoch 12/15
# 26/26 [==============================] - 1s 30ms/step - loss: 0.2023 - accuracy: 0.9337
# Epoch 13/15
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1961 - accuracy: 0.9366
# Epoch 14/15
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1904 - accuracy: 0.9388
# Epoch 15/15
# 26/26 [==============================] - 1s 29ms/step - loss: 0.1851 - accuracy: 0.9406
# 46/46 [==============================] - 0s 3ms/step - loss: 0.5461 - accuracy: 0.8094
#
# Test accuracy: 80.94%

# %%
reg_results = test_model(reg_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, reg_min)
# Out:
# Epoch 1/6
# 26/26 [==============================] - 1s 54ms/step - loss: 0.2717 - accuracy: 0.9523
# Epoch 2/6
# 26/26 [==============================] - 2s 73ms/step - loss: 0.2411 - accuracy: 0.9606
# Epoch 3/6
# 26/26 [==============================] - 2s 76ms/step - loss: 0.2261 - accuracy: 0.9669
# Epoch 4/6
# 26/26 [==============================] - 1s 49ms/step - loss: 0.2164 - accuracy: 0.9681
# Epoch 5/6
# 26/26 [==============================] - 1s 51ms/step - loss: 0.2076 - accuracy: 0.9715
# Epoch 6/6
# 26/26 [==============================] - 1s 50ms/step - loss: 0.2030 - accuracy: 0.9743
# 46/46 [==============================] - 0s 5ms/step - loss: 0.7580 - accuracy: 0.8005
#
# Test accuracy: 80.05%

# %%
drop_results = test_model(drop_model, X_train_oh, y_train_oh, X_test_oh, y_test_oh, drop_min)
# Out:
# Epoch 1/6
# 26/26 [==============================] - 1s 51ms/step - loss: 0.2105 - accuracy: 0.9364
# Epoch 2/6
# 26/26 [==============================] - 1s 54ms/step - loss: 0.1859 - accuracy: 0.9414
# Epoch 3/6
# 26/26 [==============================] - 1s 51ms/step - loss: 0.1707 - accuracy: 0.9463
# Epoch 4/6
# 26/26 [==============================] - 2s 76ms/step - loss: 0.1623 - accuracy: 0.9501
# Epoch 5/6
# 26/26 [==============================] - 2s 74ms/step - loss: 0.1525 - accuracy: 0.9527
# Epoch 6/6
# 26/26 [==============================] - 1s 50ms/step - loss: 0.1370 - accuracy: 0.9577
# 46/46 [==============================] - 0s 3ms/step - loss: 0.7022 - accuracy: 0.8108
#
# Test accuracy: 81.08%

# %% [markdown]
# # Handling Underfitting
# * In a general situation, the best strategy is to increase the model complexity by either increasing the number of parameters of your deep learning model or the order of your model. Underfitting is due to the model being simpler than needed. It fails to capture the patterns in the data. Increasing the model complexity will lead to improvement in training performance. If we use a large enough model it can even achieve a training error of zero i.e. the model will memorize the data and suffer from over-fitting. The goal is to hit the optimal sweet spot.
# * Try to train the model for more epochs. Ensure that the loss is decreasing gradually over the course of the training. Otherwise, it is highly likely that there is some kind of bug or problem in the training code/logic itself.
# * If you aren’t shuffling the data after every epoch, it can harm the model performance. Ensuring that you are shuffling the data is a good check to perform at this point.

# %% [markdown]
# #Conclusion
# To recap: here are the most common ways to prevent overfitting in neural networks:
#
# * Get more training data.
# * Reduce the capacity of the network.
# * Add weight regularization.
# * Add dropout.
#
# Two important approaches not covered in this guide are:
#
# * data-augmentation
# * batch normalization
#
# Remember that each method can help on its own, but often combining them can be even more effective.
#
# here are the ways to prevent underfitting
#
# * Get more training data.
# * Increase the size or number of parameters in the model.
# * Increase the complexity of the model.
# * Increasing the training time, until cost function is minimised.

# %% [markdown]
# # Bonus content - Visualizing L2 regularization

# %%
import numpy as np
#%matplotlib notebook
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.core.debugger import set_trace
import warnings
warnings.filterwarnings('ignore')
import itertools

# %%
def plot_contour(f, x1bound, x2bound, resolution, ax):
    x1range = np.linspace(x1bound[0], x1bound[1], resolution)
    x2range = np.linspace(x2bound[0], x2bound[1], resolution)
    xg, yg = np.meshgrid(x1range, x2range)
    zg = np.zeros_like(xg)
    for i,j in itertools.product(range(resolution), range(resolution)):
        zg[i,j] = f([xg[i,j], yg[i,j]])
    ax.contour(xg, yg, zg, 100)
    return ax

# %% [markdown]
# Let's create a toy data:

# %%
N = 20
x = np.random.rand(N) * 10
y = -4*x + 10 + 2*np.random.randn(N)

# %% [markdown]
# visualize the regularized **cost function**

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l2_penalty = lambda w: np.dot(w,w)/2
cost_plus_l2 = lambda w: cost(w) + 5*l2_penalty(w)

fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l2_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L2 reg. $||w||_2^2$')
plot_contour(cost_plus_l2, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L2 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 1
#
# Plot the same for L1 regularization

# %% [markdown]
# ### Answer

# %%
cost = lambda w: .5*np.mean((w[0] + w[1]*x - y)**2)
l1_penalty = lambda w: np.sum(np.abs(w))
cost_plus_l1 = lambda w: cost(w) + 5*l1_penalty(w)


fig, axes = plt.subplots(ncols=3, nrows=1, constrained_layout=True, figsize=(15, 5))
plot_contour(cost, [-20,20], [-20,20], 50, axes[0])
axes[0].set_title(r'cost function $J(w)$')
plot_contour(l1_penalty, [-20,20], [-20,20], 50, axes[1])
axes[1].set_title(r'L1 reg. $||w||_2^2$')
plot_contour(cost_plus_l1, [-20,20], [-20,20], 50, axes[2])
axes[2].set_title(r'L1 reg. cost $J(w) + 5 ||w||_2^2$')
plt.show()

# %% [markdown]
# ## Bonus Question 2
# After looking at the visualization to what the L1 and L2 normalizations, how do they help while training?
#
# L1 is useful for high-dimensional data, helping to create simpler, more interpretable models.
#
# L2 helps when features are highly correlated , preventing any single feature from having an overly large weight, thus reducing overfitting.

# %% [markdown]
# # Upload this Colab Notebook to your Github repository. Also add your *reflections* on today's learning in README.md
